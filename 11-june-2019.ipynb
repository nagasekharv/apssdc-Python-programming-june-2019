# %% [markdown]
# ###
# NOTE BOOKS

# %% [markdown]
# ### NOTEBOOKS BASICS
#
#     * Changing the mode from markdown to python press 'y' on left of the cell.
#     * Changing the mode from python code to markdown press 'm' on left the cell.
#
# * **BOlD**<br>
# * *italic*<br>
# * ***b***<br>
# * Normal Text
#     * sublist-1
#         * sublist-2
#
#
# > 1. OrderedList list 1
# > 2. OrderedList list 2
#
# - [y] Option 1
# - [x] Option 2
# - [x] Option 3
#
#
# [Jupyter-logo](jupyter-image.jpg)
# ![Jupyter-logo](jupyter-image.jpg)
# <img src="jupyter-image.jpg" style="float:left;height:300px;width:300px">
#
# Iget 10 times more traffic from [Google] [1] than from [Yahoo] [2] or [MSN] [3].
#
# [1]: http://google.com/
# [2]: http://search.yahoo.com/ "Yahoo search"
#
#
# ```printf("hello world")```
#
# <a><http://www.google.com></a>

# %% [markdown]
# #Python Basics

# %% [markdown]
# # Python Basics
# ## Python version 3.7
# - Scripting
# - Object oriented
# - Functional

# %% [markdown]
# ### **Python Comments**

# %%
# python Comment

print("Good Afternoon","!",end=" ") # Basic output
print("Hello python")
# Out:
# Good Afternoon ! Hello python

# %% [markdown]
# ### Assignment

# %%
n1 = 123456 # Single variable Assignment

n2=n3=n4=n1 #Multi variable Assignment of the variable

n3
a,b,c = 123,234,345 # Multi variable Assignment with different values

a
b
c

print(a,b,c)

a,b,c
# Out:
# 123 234 345
# (123, 234, 345)

# %% [markdown]
# ### ARITHMETIC OPERATORS
# - +
# - -
# - *
# - /
# - %
# - **

# %%
a
# Out:
# 123

# %%
a%11 
n3 = a**121123

type(n3)
n3
#len(str(n3))
# Out:
# ...

# %% [markdown]
# ## Conditionals

# %%
a<=123
print(a<=123,a<123)
# Out:
# True False

# %% [markdown]
# ## Data Types & Conversions
# - int
# - float
# - string
# - double

# %%
type(a)
s1 = "python"
type(s1)

f1 = 12.345
type(f1)

str(int(f1)) #converting to int
float(str(int(f1)))
# Out:
# 12.0

# %%
atoms = 10 **89
if atoms < 10 ** 9:
    print("true")
else:
    print("False")
# Out:
# False

# %%
# Calculate if a number is multiple of 10
if 12%10==0:
    print(12,"is multiple of 10")
else:
        print(12,"is not a multiple of 10")
# Out:
# 12 is not a multiple of 10

# %%
# check if given string is equal to a numbe
